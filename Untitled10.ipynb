# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#Printing top 5 rows of the dataset
df.head(6)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
#Finding the missing values in the given data
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
#number of rows and columns
df.shape
# Out:
# (200, 4)

# %%
sns.scatterplot(x=df["TV"], y=df["Sales"])
plt.show()

# %%
plt.scatter(df["Radio"],df["Sales"], color='r')
plt.xlabel("Radio")
plt.ylabel("Sales")
plt.show()

# %%
sns.scatterplot(x=df["Newspaper"], y=df["Sales"],color ='b')
plt.show()

# %%
sns.lmplot(x='TV', y='Sales', data=df)
sns.lmplot(x='Radio', y='Sales', data=df)
sns.lmplot(x='Newspaper', y='Sales', data=df)
# Out:
# C:\Users\desai\anaconda32\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\desai\anaconda32\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\desai\anaconda32\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10,7))

plt.subplot(221)
plt.hist(df['TV'],color='black')
plt.title('TV')

plt.subplot(222)
plt.hist(df['Radio'],color='b')
plt.title('Radio')

plt.subplot(223)
plt.hist(df['Newspaper'],color='g')
plt.title('Newspaper')

plt.subplot(224)
plt.hist(df['Sales'],color='purple')
plt.title('Sales')

plt.show()

# %%
sns.heatmap(df.corr(), annot=True, fmt='.2f')
plt.title("correlation of advertising mediums with Sales")
plt.show()

# %%
print(df.columns)
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
# Ensure necessary libraries are imported
from sklearn.model_selection import train_test_split

# Assuming df is a DataFrame and 'TV' and 'sales' are column names
X = df[['TV']]
Y = df[['Sales']]

# Splitting the data into training and testing datasets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Displaying the results
print("X_train:")
print(X_train)
print("\nY_train:")
print(Y_train)
print("\nX_test:")
print(X_test)
print("\nY_test:")
print(Y_test)
# Out:
# X_train:
#         TV
# 134   36.9
# 66    31.5
# 26   142.9
# 113  209.6
# 168  215.4
# ..     ...
# 67   139.3
# 192   17.2
# 117   76.4
# 47   239.9
# 172   19.6
#
# [160 rows x 1 columns]
#
# Y_train:
#      Sales
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [160 rows x 1 columns]
#
# X_test:
#         TV
# 18    69.2
# 170   50.0
# 107   90.4
# 98   289.7
# 177  170.2
# 182   56.2
# 5      8.7
# 146  240.1
# 12    23.8
# 152  197.6
# 61   261.3
# 125   87.2
# 180  156.6
# 154  187.8
# 80    76.4
# 7    120.2
# 33   265.6
# 130    0.7
# 37    74.7
# 74   213.4
# 183  287.6
# 145  140.3
# 45   175.1
# 159  131.7
# 60    53.5
# 123  123.1
# 179  165.6
# 185  205.0
# 122  224.0
# 44    25.1
# 16    67.8
# 55   198.9
# 150  280.7
# 111  241.7
# 22    13.2
# 189   18.7
# 129   59.6
# 4    180.8
# 83    68.4
# 106   25.0
#
# Y_test:
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# ...

# %%
# Import LinearRegression from sklearn
from sklearn.linear_model import LinearRegression

# Create a LinearRegression model
ML = LinearRegression()

# Fit the model using the training data
ML.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_train_prediction=ML.predict(X_train)
print(X_train_prediction)
# Out:
# [[ 9.16343282]
#  [ 8.86788005]
#  [14.96502414]
#  [18.61564811]
#  [18.93309367]
#  [12.76479799]
#  [ 7.6145174 ]
#  [ 8.06879294]
#  [14.02363385]
#  [12.86878878]
#  [13.15339515]
#  [19.70481478]
#  [21.03480222]
#  [17.26376787]
#  [ 9.59034237]
#  [10.55362545]
#  [23.17482317]
#  [16.58509115]
#  [18.22705095]
#  [ 7.54336581]
#  [21.65874695]
#  [17.95886418]
#  [19.10276285]
#  [15.20584491]
#  [16.51941275]
#  [19.05897726]
#  [21.52191697]
#  [16.0925032 ]
#  [12.63891441]
#  [11.31987336]
#  [17.26376787]
#  [14.49432899]
#  [22.1239689 ]
#  [23.36638515]
#  [12.40904004]
#  [13.15339515]
#  [21.12237341]
#  [18.31462214]
#  [20.28497391]
#  [17.74540941]
#  [17.60310623]
#  [12.05328208]
#  [ 9.49729798]
#  [ 9.23458441]
#  [ 7.86081137]
#  [20.24118832]
#  [ 8.08521254]
#  [18.6758533 ]
#  [ 8.54496129]
#  [16.83138512]
#  [18.46787172]
#  [10.76160703]
#  [15.33720169]
#  [14.22614222]
#  [12.29957605]
#  [22.28816488]
#  [22.29911127]
#  [ 7.5707318 ]
# ...

# %%
print(Y_train)
# Out:
#      Sales
# 134   10.8
# 66    11.0
# 26    15.0
# 113   20.9
# 168   17.1
# ..     ...
# 67    13.4
# 192    5.9
# 117    9.4
# 47    23.2
# 172    7.6
#
# [160 rows x 1 columns]

# %%
print(ML.coef_)
print(ML.intercept_)
# Out:
# [[0.0544343]]
# [7.16227597]

# %%
X_test_prediction = ML.predict(X_test)
print(X_test_prediction)
# Out:
# [[10.92912965]
#  [ 9.88399105]
#  [12.08313684]
#  [22.93189318]
#  [16.42699412]
#  [10.22148373]
#  [ 7.63585439]
#  [20.23195181]
#  [ 8.45781235]
#  [17.91849399]
#  [21.38595901]
#  [11.90894708]
#  [15.68668762]
#  [17.38503783]
#  [11.32105662]
#  [13.70527904]
#  [21.62002651]
#  [ 7.20037998]
#  [11.22851831]
#  [18.77855596]
#  [22.81758114]
#  [14.7994085 ]
#  [16.6937222 ]
#  [14.33127351]
#  [10.07451111]
#  [13.86313851]
#  [16.17659633]
#  [18.32130782]
#  [19.35555956]
#  [ 8.52857694]
#  [10.85292163]
#  [17.98925858]
#  [22.44198446]
#  [20.3190467 ]
#  [ 7.88080875]
#  [ 8.18019741]
#  [10.40656035]
#  [17.00399772]
#  [10.88558221]
#  [ 8.52313351]]

# %%
print(Y_test)
# Out:
#      Sales
# 18    11.3
# 170    8.4
# 107   12.0
# 98    25.4
# 177   16.7
# 182    8.7
# 5      7.2
# 146   18.2
# 12     9.2
# 152   16.6
# 61    24.2
# 125   10.6
# 180   15.5
# 154   20.6
# 80    11.8
# 7     13.2
# 33    17.4
# 130    1.6
# 37    14.7
# 74    17.0
# 183   26.2
# 145   10.3
# 45    16.1
# 159   12.9
# 60     8.1
# 123   15.2
# 179   17.6
# 185   22.6
# 122   16.6
# 44     8.5
# 16    12.5
# 55    23.7
# 150   16.1
# 111   21.8
# 22     5.6
# 189    6.7
# 129    9.7
# 4     17.9
# 83    13.6
# 106    7.2

# %%
import matplotlib.pyplot as plt

# Assuming you have already made predictions on the training data
X_train_prediction = ML.predict(X_train)

# Plot histogram comparison between original and predicted values
plt.figure(figsize=[7,5])

# Plot the histogram for original values
plt.hist(Y_train, bins=15, alpha=0.5, label='Original values')

# Plot the histogram for predicted values
plt.hist(X_train_prediction, bins=15, alpha=0.5, label='Predicted values')

# Adding labels and title
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram Comparison: Original vs Predicted values")
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have already made predictions on the test data
X_test_prediction = ML.predict(X_test)

# Plot histogram comparison between original and predicted values
plt.figure(figsize=[7,5])

# Plot the histogram for original values
plt.hist(Y_test, bins=15, alpha=0.5, label='Original values')

# Plot the histogram for predicted values
plt.hist(X_test_prediction, bins=15, alpha=0.5, label='Predicted values')

# Adding labels and title
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.title("Histogram Comparison: Original vs Predicted values")
plt.legend()

# Show plot
plt.show()
